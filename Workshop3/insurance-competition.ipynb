# %% [markdown]
# # <p style="font-family: 'Amiri'; font-size: 3rem; color: yellow; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #5fa1bc; padding: 20px; border-radius: 20px; border: 7px solid yellow; width:95%">˚ ༘ ೀ⋆｡🚀  A Dive into Regression with an insurance Dataset 📚˚ ༘ ೀ⋆｡ ˚</p>

# %% [markdown]
# ![_08d25f79-0e9b-447e-a629-9ad987f356a1.jpeg](attachment:52b1f155-dcf1-4dfd-812a-19acc9567f11.jpeg)

# %% [markdown]
# # <p style="font-family: 'Amiri'; font-size: 3rem; color: yellow; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #5fa1bc; padding: 20px; border-radius: 20px; border: 7px solid yellow; width:95%">˚ ༘ ೀ⋆｡ About The Auther  ˚ ༘ ೀ⋆｡ ˚</p>

# %% [markdown]
# <div style="border: 2px solid #14adc6; padding: 10px; max-width: 1000px; margin: 0 auto;">
#     <p>
#         "Alone we can do so little; together we can do so much." - Helen Keller 🌟
#     </p>
#     <p>
#         I am <b>Saman Fatima</b>, a passionate data scientist dedicated to mastering machine learning techniques and continually expanding my knowledge base. I believe in the mantra of KeepLearning and KeepSupporting, as I am committed to constant growth and uplifting others in the field. 🚀
#     </p>
#     <div style="text-align: center;">
#         <img src="https://media.licdn.com/dms/image/D4D03AQFAcZhjvE7C0Q/profile-displayphoto-shrink_800_800/0/1714558384812?e=1721260800&v=beta&t=vfqq1fnuYMej7Tpr_MGPhs1c9DuVyJHbzZT0XuacRds" alt="Profile Picture" style="width: 100px; height: 100px; border-radius: 50%; border: 2px solid #14adc6;"><br>
#     </div>
#     <p>
#         You can find more about me on my <a href="https://www.linkedin.com/in/saman-fatima-datascience/" target="_blank">LinkedIn</a>.<br>
#         Feel free to connect and reach out for any collaboration or queries! 📊
#     </p>
#     <p>My skills include:</p>
#     <ul style="list-style-type: disc; margin-left: 20px;">
#         <li>Data Analysis 📉</li>
#         <li>Machine Learning 🤖</li>
#         <li>Deep Learning 🧠</li>
#         <li>Statistical Modeling 📈</li>
#         <li>Data Visualization 📊</li>
#     </ul>
#     <p> If you find any content helpful, consider giving it an upvote. Your support means a lot! 👍</p>
# </div>

# %% [markdown]
# # <p style="font-family: 'Amiri'; font-size: 3rem; color: yellow; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #5fa1bc; padding: 20px; border-radius: 20px; border: 7px solid yellow; width:95%">˚ ༘ ೀ⋆｡ Importing The Libraries  ˚ ༘ ೀ⋆｡ ˚</p>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px
from IPython.display import display, HTML
import warnings
from colorama import Fore, Style
from catboost import CatBoostClassifier

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer, OneHotEncoder, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, f1_score, roc_auc_score
from scipy.stats import randint
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import lightgbm as lgb
from catboost import CatBoostRegressor
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import LabelEncoder
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.model_selection import KFold
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings('ignore')

# %% [markdown]
# # <p style="font-family: 'Amiri'; font-size: 3rem; color: yellow; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #5fa1bc; padding: 20px; border-radius: 20px; border: 7px solid yellow; width:95%">˚ ༘ ೀ⋆｡ Loading The Dataset˚ ༘ ೀ⋆｡ ˚</p>

# %%
df_tr = pd.read_csv('/kaggle/input/playground-series-s4e12/train.csv')
df_ts = pd.read_csv('/kaggle/input/playground-series-s4e12/test.csv')
df_s = pd.read_csv('/kaggle/input/playground-series-s4e12/sample_submission.csv')

# %% [markdown]
# # <p style="font-family: 'Amiri'; font-size: 3rem; color: yellow; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #5fa1bc; padding: 20px; border-radius: 20px; border: 7px solid yellow; width:95%">˚ ༘ ೀ⋆｡ SneakPeak Of The Data ˚ ༘ ೀ⋆｡ ˚</p>

# %% [markdown]
# <span style="font-size: 14px; font-family: Verdana; background-color: #5fa1bc; color: white; border: 2px solid #ccc; padding: 10px; border-radius: 10px; display: inline-block;">
#   I've created a convenient function to display detailed information about the dataset with just one click. This function provides essential insights into the dataset's structure, summary statistics, and data types, allowing for a quick understanding of its contents. Feel free to utilize this function in your analysis, but please ensure to give proper reference when using it. Your support and acknowledgment are greatly appreciated!
# </span>

# %%
def styled_heading(text):
    return f"""
    <p style="
        font-family: 'Amiri'; 
        font-size: 3rem; 
        color: yellow; 
        text-align: center; 
        margin: 0; 
        text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); 
        background-color: #5fa1bc; 
        padding: 20px; 
        border-radius: 20px; 
        border: 7px solid yellow; 
        width:95%">
        {text}
    </p>
    """

def print_error(message):
    display(HTML(styled_heading("Error")))
    print(f"An error occurred: {message}")

# Helper function to generate colored horizontal line
def colored_line(color='#323c6a'):
    return ""

def print_dataset_analysis(train_dataset, test_dataset, n_top=5, heading_color='#323c6a', line_color='#323c6a'):
    try:
        # Printing top values
        train_heading = styled_heading(f"🔝 Top {n_top} rows of Training Dataset")
        test_heading = styled_heading(f"🔝 Top {n_top} rows of Test Dataset")

        display(HTML(colored_line(line_color)))
        display(HTML(train_heading))
        display(HTML(colored_line(line_color)))
        display(HTML(train_dataset.head(n_top).to_html()))

        display(HTML(colored_line(line_color)))
        display(HTML(test_heading))
        display(HTML(colored_line(line_color)))
        display(HTML(test_dataset.head(n_top).to_html()))
        
        # Printing dataset summary
        summary_heading = styled_heading("📊 Summary of Dataset")
        display(HTML(colored_line(line_color)))
        display(HTML(summary_heading))
        display(HTML(colored_line(line_color)))
        display(HTML(train_dataset.describe().to_html()))

        # Printing null values
        null_heading = styled_heading("❌ Null Values in Datasets")
        
        train_null_count = train_dataset.isnull().sum()
        test_null_count = test_dataset.isnull().sum()

        display(HTML(colored_line(line_color)))
        display(HTML(null_heading))
        display(HTML(colored_line(line_color)))
        display(HTML("<h3>Training Dataset:</h3>"))
        if train_null_count.sum() == 0:
            display(HTML("<p>No null values in the training dataset.</p>"))
        else:
            display(HTML(train_null_count[train_null_count > 0].to_frame().to_html()))
            display(HTML("<p>These are the null values.</p>"))

        display(HTML("<h3>Test Dataset:</h3>"))
        if test_null_count.sum() == 0:
            display(HTML("<p>No null values in the test dataset.</p>"))
        else:
            display(HTML(test_null_count[test_null_count > 0].to_frame().to_html()))
            display(HTML("<p>These are the null values.</p>"))

        # Printing duplicate values
        duplicate_heading = styled_heading("♻️ Duplicate Values in Datasets")
        
        train_duplicates = train_dataset.duplicated().sum()
        test_duplicates = test_dataset.duplicated().sum()

        display(HTML(colored_line(line_color)))
        display(HTML(duplicate_heading))
        display(HTML(colored_line(line_color)))
        display(HTML("<h3>Training Dataset:</h3>"))
        display(HTML(f"<p>{train_duplicates} duplicate rows</p>"))

        display(HTML("<h3>Test Dataset:</h3>"))
        display(HTML(f"<p>{test_duplicates} duplicate rows</p>"))
        
        # Printing number of rows and columns
        shape_heading = styled_heading("📏 Number of Rows and Columns")
        display(HTML(colored_line(line_color)))
        display(HTML(shape_heading))
        display(HTML(colored_line(line_color)))
        display(HTML("<h3>Training Dataset:</h3>"))
        display(HTML(f"<p>Rows: {train_dataset.shape[0]}, Columns: {train_dataset.shape[1]}</p>"))
        display(HTML("<h3>Test Dataset:</h3>"))
        display(HTML(f"<p>Rows: {test_dataset.shape[0]}, Columns: {test_dataset.shape[1]}</p>"))

    except Exception as e:
        print_error(str(e))

def print_unique_values(test_dataset, heading_color='#323c6a', line_color='#323c6a'):
    try:
        unique_values_heading = styled_heading("🔢 Unique Values in Training Dataset")
        
        display(HTML(colored_line(line_color)))
        display(HTML(unique_values_heading))
        display(HTML(colored_line(line_color)))
        
        unique_values_table = "<table border='1'><tr><th>Column Name</th><th>Data Type</th><th>Unique Values</th></tr>"
        
        for column in test_dataset.columns:
            unique_values = test_dataset[column].unique()[:7]  # Taking at least 7 unique values
            unique_values_str = ', '.join(map(str, unique_values))
            data_type = test_dataset[column].dtype
            unique_values_table += f"<tr><td>{column}</td><td>{data_type}</td><td>{unique_values_str}</td></tr>"
        
        unique_values_table += "</table>"
        display(HTML(unique_values_table))
    
    except Exception as e:
        print_error(str(e))

# %%
print_dataset_analysis(df_tr, df_ts)
print_unique_values(df_tr)
# Out:
#     <p style="
#         font-family: 'Amiri';
#         font-size: 3rem;
#         color: yellow;
#         text-align: center;
#         margin: 0;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);
#         background-color: #5fa1bc;
#         padding: 20px;
#         border-radius: 20px;
#         border: 7px solid yellow;
#         width:95%">
#         🔝 Top 5 rows of Training Dataset
#     </p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>Age</th>
#       <th>Gender</th>
#       <th>Annual Income</th>
#       <th>Marital Status</th>
#       <th>Number of Dependents</th>
#       <th>Education Level</th>
#       <th>Occupation</th>
#       <th>Health Score</th>
#       <th>Location</th>
#       <th>Policy Type</th>
#       <th>Previous Claims</th>
#       <th>Vehicle Age</th>
#       <th>Credit Score</th>
#       <th>Insurance Duration</th>
#       <th>Policy Start Date</th>
#       <th>Customer Feedback</th>
#       <th>Smoking Status</th>
#       <th>Exercise Frequency</th>
#       <th>Property Type</th>
#       <th>Premium Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>19.0</td>
#       <td>Female</td>
#       <td>10049.0</td>
#       <td>Married</td>
#       <td>1.0</td>
#       <td>Bachelor's</td>
#       <td>Self-Employed</td>
#       <td>22.598761</td>
#       <td>Urban</td>
#       <td>Premium</td>
#       <td>2.0</td>
#       <td>17.0</td>
#       <td>372.0</td>
#       <td>5.0</td>
#       <td>2023-12-23 15:21:39.134960</td>
#       <td>Poor</td>
#       <td>No</td>
#       <td>Weekly</td>
#       <td>House</td>
#       <td>2869.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>39.0</td>
#       <td>Female</td>
#       <td>31678.0</td>
#       <td>Divorced</td>
#       <td>3.0</td>
#       <td>Master's</td>
#       <td>NaN</td>
#       <td>15.569731</td>
#       <td>Rural</td>
#       <td>Comprehensive</td>
#       <td>1.0</td>
#       <td>12.0</td>
#       <td>694.0</td>
#       <td>2.0</td>
#       <td>2023-06-12 15:21:39.111551</td>
#       <td>Average</td>
#       <td>Yes</td>
#       <td>Monthly</td>
#       <td>House</td>
#       <td>1483.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>23.0</td>
#       <td>Male</td>
#       <td>25602.0</td>
#       <td>Divorced</td>
#       <td>3.0</td>
#       <td>High School</td>
#       <td>Self-Employed</td>
#       <td>47.177549</td>
#       <td>Suburban</td>
#       <td>Premium</td>
#       <td>1.0</td>
#       <td>14.0</td>
#       <td>NaN</td>
#       <td>3.0</td>
#       <td>2023-09-30 15:21:39.221386</td>
#       <td>Good</td>
#       <td>Yes</td>
#       <td>Weekly</td>
#       <td>House</td>
#       <td>567.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>21.0</td>
#       <td>Male</td>
#       <td>141855.0</td>
#       <td>Married</td>
#       <td>2.0</td>
#       <td>Bachelor's</td>
#       <td>NaN</td>
#       <td>10.938144</td>
#       <td>Rural</td>
#       <td>Basic</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>367.0</td>
#       <td>1.0</td>
#       <td>2024-06-12 15:21:39.226954</td>
#       <td>Poor</td>
#       <td>Yes</td>
#       <td>Daily</td>
#       <td>Apartment</td>
#       <td>765.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>21.0</td>
#       <td>Male</td>
#       <td>39651.0</td>
#       <td>Single</td>
#       <td>1.0</td>
#       <td>Bachelor's</td>
#       <td>Self-Employed</td>
#       <td>20.376094</td>
#       <td>Rural</td>
#       <td>Premium</td>
#       <td>0.0</td>
#       <td>8.0</td>
#       <td>598.0</td>
#       <td>4.0</td>
#       <td>2021-12-01 15:21:39.252145</td>
#       <td>Poor</td>
#       <td>Yes</td>
#       <td>Weekly</td>
#       <td>House</td>
#       <td>2022.0</td>
#     </tr>
#   </tbody>
# </table>
#     <p style="
#         font-family: 'Amiri';
#         font-size: 3rem;
#         color: yellow;
#         text-align: center;
#         margin: 0;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);
#         background-color: #5fa1bc;
#         padding: 20px;
#         border-radius: 20px;
#         border: 7px solid yellow;
#         width:95%">
#         🔝 Top 5 rows of Test Dataset
#     </p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>Age</th>
#       <th>Gender</th>
#       <th>Annual Income</th>
#       <th>Marital Status</th>
#       <th>Number of Dependents</th>
#       <th>Education Level</th>
#       <th>Occupation</th>
#       <th>Health Score</th>
#       <th>Location</th>
#       <th>Policy Type</th>
#       <th>Previous Claims</th>
#       <th>Vehicle Age</th>
#       <th>Credit Score</th>
#       <th>Insurance Duration</th>
#       <th>Policy Start Date</th>
#       <th>Customer Feedback</th>
#       <th>Smoking Status</th>
#       <th>Exercise Frequency</th>
#       <th>Property Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1200000</td>
#       <td>28.0</td>
#       <td>Female</td>
#       <td>2310.0</td>
#       <td>NaN</td>
#       <td>4.0</td>
#       <td>Bachelor's</td>
#       <td>Self-Employed</td>
#       <td>7.657981</td>
#       <td>Rural</td>
#       <td>Basic</td>
#       <td>NaN</td>
#       <td>19.0</td>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2023-06-04 15:21:39.245086</td>
#       <td>Poor</td>
#       <td>Yes</td>
#       <td>Weekly</td>
#       <td>House</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1200001</td>
#       <td>31.0</td>
#       <td>Female</td>
#       <td>126031.0</td>
#       <td>Married</td>
#       <td>2.0</td>
#       <td>Master's</td>
#       <td>Self-Employed</td>
#       <td>13.381379</td>
#       <td>Suburban</td>
#       <td>Premium</td>
#       <td>NaN</td>
#       <td>14.0</td>
#       <td>372.0</td>
#       <td>8.0</td>
#       <td>2024-04-22 15:21:39.224915</td>
#       <td>Good</td>
#       <td>Yes</td>
#       <td>Rarely</td>
#       <td>Apartment</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1200002</td>
#       <td>47.0</td>
#       <td>Female</td>
#       <td>17092.0</td>
#       <td>Divorced</td>
#       <td>0.0</td>
#       <td>PhD</td>
#       <td>Unemployed</td>
#       <td>24.354527</td>
#       <td>Urban</td>
#       <td>Comprehensive</td>
#       <td>NaN</td>
#       <td>16.0</td>
#       <td>819.0</td>
#       <td>9.0</td>
#       <td>2023-04-05 15:21:39.134960</td>
#       <td>Average</td>
#       <td>Yes</td>
#       <td>Monthly</td>
#       <td>Condo</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1200003</td>
#       <td>28.0</td>
#       <td>Female</td>
#       <td>30424.0</td>
#       <td>Divorced</td>
#       <td>3.0</td>
#       <td>PhD</td>
#       <td>Self-Employed</td>
#       <td>5.136225</td>
#       <td>Suburban</td>
#       <td>Comprehensive</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>770.0</td>
#       <td>5.0</td>
#       <td>2023-10-25 15:21:39.134960</td>
#       <td>Poor</td>
#       <td>Yes</td>
#       <td>Daily</td>
#       <td>House</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1200004</td>
#       <td>24.0</td>
#       <td>Male</td>
#       <td>10863.0</td>
#       <td>Divorced</td>
#       <td>2.0</td>
#       <td>High School</td>
#       <td>Unemployed</td>
#       <td>11.844155</td>
#       <td>Suburban</td>
#       <td>Premium</td>
#       <td>NaN</td>
#       <td>14.0</td>
#       <td>755.0</td>
#       <td>7.0</td>
#       <td>2021-11-26 15:21:39.259788</td>
#       <td>Average</td>
#       <td>No</td>
#       <td>Weekly</td>
#       <td>House</td>
#     </tr>
#   </tbody>
# </table>
#     <p style="
#         font-family: 'Amiri';
#         font-size: 3rem;
#         color: yellow;
#         text-align: center;
#         margin: 0;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);
#         background-color: #5fa1bc;
#         padding: 20px;
#         border-radius: 20px;
#         border: 7px solid yellow;
#         width:95%">
#         📊 Summary of Dataset
#     </p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>Age</th>
#       <th>Annual Income</th>
#       <th>Number of Dependents</th>
#       <th>Health Score</th>
#       <th>Previous Claims</th>
#       <th>Vehicle Age</th>
#       <th>Credit Score</th>
#       <th>Insurance Duration</th>
#       <th>Premium Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>1.200000e+06</td>
#       <td>1.181295e+06</td>
#       <td>1.155051e+06</td>
#       <td>1.090328e+06</td>
#       <td>1.125924e+06</td>
#       <td>835971.000000</td>
#       <td>1.199994e+06</td>
#       <td>1.062118e+06</td>
#       <td>1.199999e+06</td>
#       <td>1.200000e+06</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>5.999995e+05</td>
#       <td>4.114556e+01</td>
#       <td>3.274522e+04</td>
#       <td>2.009934e+00</td>
#       <td>2.561391e+01</td>
#       <td>1.002689</td>
#       <td>9.569889e+00</td>
#       <td>5.929244e+02</td>
#       <td>5.018219e+00</td>
#       <td>1.102545e+03</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>3.464103e+05</td>
#       <td>1.353995e+01</td>
#       <td>3.217951e+04</td>
#       <td>1.417338e+00</td>
#       <td>1.220346e+01</td>
#       <td>0.982840</td>
#       <td>5.776189e+00</td>
#       <td>1.499819e+02</td>
#       <td>2.594331e+00</td>
#       <td>8.649989e+02</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.000000e+00</td>
#       <td>1.800000e+01</td>
#       <td>1.000000e+00</td>
#       <td>0.000000e+00</td>
#       <td>2.012237e+00</td>
#       <td>0.000000</td>
#       <td>0.000000e+00</td>
#       <td>3.000000e+02</td>
#       <td>1.000000e+00</td>
#       <td>2.000000e+01</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.999998e+05</td>
#       <td>3.000000e+01</td>
#       <td>8.001000e+03</td>
#       <td>1.000000e+00</td>
#       <td>1.591896e+01</td>
#       <td>0.000000</td>
#       <td>5.000000e+00</td>
#       <td>4.680000e+02</td>
#       <td>3.000000e+00</td>
#       <td>5.140000e+02</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>5.999995e+05</td>
#       <td>4.100000e+01</td>
#       <td>2.391100e+04</td>
#       <td>2.000000e+00</td>
#       <td>2.457865e+01</td>
#       <td>1.000000</td>
#       <td>1.000000e+01</td>
#       <td>5.950000e+02</td>
#       <td>5.000000e+00</td>
#       <td>8.720000e+02</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>8.999992e+05</td>
#       <td>5.300000e+01</td>
#       <td>4.463400e+04</td>
#       <td>3.000000e+00</td>
#       <td>3.452721e+01</td>
#       <td>2.000000</td>
#       <td>1.500000e+01</td>
#       <td>7.210000e+02</td>
#       <td>7.000000e+00</td>
#       <td>1.509000e+03</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>1.199999e+06</td>
#       <td>6.400000e+01</td>
#       <td>1.499970e+05</td>
#       <td>4.000000e+00</td>
#       <td>5.897591e+01</td>
#       <td>9.000000</td>
#       <td>1.900000e+01</td>
#       <td>8.490000e+02</td>
#       <td>9.000000e+00</td>
#       <td>4.999000e+03</td>
#     </tr>
#   </tbody>
# </table>
#     <p style="
#         font-family: 'Amiri';
#         font-size: 3rem;
#         color: yellow;
#         text-align: center;
#         margin: 0;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);
#         background-color: #5fa1bc;
#         padding: 20px;
#         border-radius: 20px;
#         border: 7px solid yellow;
#         width:95%">
#         ❌ Null Values in Datasets
#     </p>
# <h3>Training Dataset:</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Age</th>
#       <td>18705</td>
#     </tr>
#     <tr>
#       <th>Annual Income</th>
#       <td>44949</td>
#     </tr>
#     <tr>
#       <th>Marital Status</th>
#       <td>18529</td>
#     </tr>
#     <tr>
#       <th>Number of Dependents</th>
#       <td>109672</td>
#     </tr>
#     <tr>
#       <th>Occupation</th>
#       <td>358075</td>
#     </tr>
#     <tr>
#       <th>Health Score</th>
#       <td>74076</td>
#     </tr>
#     <tr>
#       <th>Previous Claims</th>
#       <td>364029</td>
#     </tr>
#     <tr>
#       <th>Vehicle Age</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Credit Score</th>
#       <td>137882</td>
#     </tr>
#     <tr>
#       <th>Insurance Duration</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Customer Feedback</th>
#       <td>77824</td>
#     </tr>
#   </tbody>
# </table>
# <p>These are the null values.</p>
# <h3>Test Dataset:</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Age</th>
#       <td>12489</td>
#     </tr>
#     <tr>
#       <th>Annual Income</th>
#       <td>29860</td>
#     </tr>
#     <tr>
#       <th>Marital Status</th>
#       <td>12336</td>
#     </tr>
#     <tr>
#       <th>Number of Dependents</th>
#       <td>73130</td>
#     </tr>
#     <tr>
#       <th>Occupation</th>
#       <td>239125</td>
#     </tr>
#     <tr>
#       <th>Health Score</th>
#       <td>49449</td>
#     </tr>
#     <tr>
#       <th>Previous Claims</th>
#       <td>242802</td>
#     </tr>
#     <tr>
#       <th>Vehicle Age</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Credit Score</th>
#       <td>91451</td>
#     </tr>
#     <tr>
#       <th>Insurance Duration</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Customer Feedback</th>
#       <td>52276</td>
#     </tr>
#   </tbody>
# </table>
# <p>These are the null values.</p>
#     <p style="
#         font-family: 'Amiri';
#         font-size: 3rem;
#         color: yellow;
#         text-align: center;
#         margin: 0;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);
#         background-color: #5fa1bc;
#         padding: 20px;
#         border-radius: 20px;
#         border: 7px solid yellow;
#         width:95%">
#         ♻️ Duplicate Values in Datasets
#     </p>
# <h3>Training Dataset:</h3>
# <p>0 duplicate rows</p>
# <h3>Test Dataset:</h3>
# <p>0 duplicate rows</p>
#     <p style="
#         font-family: 'Amiri';
#         font-size: 3rem;
#         color: yellow;
#         text-align: center;
#         margin: 0;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);
#         background-color: #5fa1bc;
#         padding: 20px;
#         border-radius: 20px;
#         border: 7px solid yellow;
#         width:95%">
#         📏 Number of Rows and Columns
#     </p>
# <h3>Training Dataset:</h3>
# <p>Rows: 1200000, Columns: 21</p>
# <h3>Test Dataset:</h3>
# <p>Rows: 800000, Columns: 20</p>
#     <p style="
#         font-family: 'Amiri';
#         font-size: 3rem;
#         color: yellow;
#         text-align: center;
#         margin: 0;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);
#         background-color: #5fa1bc;
#         padding: 20px;
#         border-radius: 20px;
#         border: 7px solid yellow;
#         width:95%">
#         🔢 Unique Values in Training Dataset
#     </p>
# <table border='1'><tr><th>Column Name</th><th>Data Type</th><th>Unique Values</th></tr><tr><td>id</td><td>int64</td><td>0, 1, 2, 3, 4, 5, 6</td></tr><tr><td>Age</td><td>float64</td><td>19.0, 39.0, 23.0, 21.0, 29.0, 41.0, 48.0</td></tr><tr><td>Gender</td><td>object</td><td>Female, Male</td></tr><tr><td>Annual Income</td><td>float64</td><td>10049.0, 31678.0, 25602.0, 141855.0, 39651.0, 45963.0, 40336.0</td></tr><tr><td>Marital Status</td><td>object</td><td>Married, Divorced, Single, nan</td></tr><tr><td>Number of Dependents</td><td>float64</td><td>1.0, 3.0, 2.0, 0.0, 4.0, nan</td></tr><tr><td>Education Level</td><td>object</td><td>Bachelor's, Master's, High School, PhD</td></tr><tr><td>Occupation</td><td>object</td><td>Self-Employed, nan, Employed, Unemployed</td></tr><tr><td>Health Score</td><td>float64</td><td>22.59876067181393, 15.569730989408043, 47.17754928786464, 10.938144158664583, 20.376093627736925, 33.05319768402281, nan</td></tr><tr><td>Location</td><td>object</td><td>Urban, Rural, Suburban</td></tr><tr><td>Policy Type</td><td>object</td><td>Premium, Comprehensive, Basic</td></tr><tr><td>Previous Claims</td><td>float64</td><td>2.0, 1.0, 0.0, nan, 3.0, 4.0, 5.0</td></tr><tr><td>Vehicle Age</td><td>float64</td><td>17.0, 12.0, 14.0, 0.0, 8.0, 4.0, 11.0</td></tr><tr><td>Credit Score</td><td>float64</td><td>372.0, 694.0, nan, 367.0, 598.0, 614.0, 807.0</td></tr><tr><td>Insurance Duration</td><td>float64</td><td>5.0, 2.0, 3.0, 1.0, 4.0, 6.0, 8.0</td></tr><tr><td>Policy Start Date</td><td>object</td><td>2023-12-23 15:21:39.134960, 2023-06-12 15:21:39.111551, 2023-09-30 15:21:39.221386, 2024-06-12 15:21:39.226954, 2021-12-01 15:21:39.252145, 2022-05-20 15:21:39.207847, 2020-02-21 15:21:39.219432</td></tr><tr><td>Customer Feedback</td><td>object</td><td>Poor, Average, Good, nan</td></tr><tr><td>Smoking Status</td><td>object</td><td>No, Yes</td></tr><tr><td>Exercise Frequency</td><td>object</td><td>Weekly, Monthly, Daily, Rarely</td></tr><tr><td>Property Type</td><td>object</td><td>House, Apartment, Condo</td></tr><tr><td>Premium Amount</td><td>float64</td><td>2869.0, 1483.0, 567.0, 765.0, 2022.0, 3202.0, 439.0</td></tr></table>

# %% [markdown]
# ----

# %% [markdown]
# # <p style="font-family: 'Amiri'; font-size: 3rem; color: yellow; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #5fa1bc; padding: 20px; border-radius: 20px; border: 7px solid yellow; width:95%">˚ ༘ ೀ⋆｡ Data Visualization˚ ༘ ೀ⋆｡ ˚</p>

# %%
def print_value_counts_less_than(df, threshold=50):
    for col in df.columns:
        value_counts = df[col].value_counts()
        if len(value_counts) < threshold:
            print(f"Value counts for column '{col}':")
            for val, count in value_counts.items():
                print(f"    {val}: {count}")
            print()

print_value_counts_less_than(df_tr, threshold=30)
# Out:
# Value counts for column 'Gender':
#     Male: 602571
#     Female: 597429
#
# Value counts for column 'Marital Status':
#     Single: 395391
#     Married: 394316
#     Divorced: 391764
#
# Value counts for column 'Number of Dependents':
#     3.0: 221475
#     4.0: 220340
#     0.0: 218124
#     2.0: 215313
#     1.0: 215076
#
# Value counts for column 'Education Level':
#     Master's: 303818
#     PhD: 303507
#     Bachelor's: 303234
#     High School: 289441
#
# Value counts for column 'Occupation':
#     Employed: 282750
#     Self-Employed: 282645
#     Unemployed: 276530
#
# Value counts for column 'Location':
#     Suburban: 401542
#     Rural: 400947
#     Urban: 397511
#
# Value counts for column 'Policy Type':
#     Premium: 401846
#     Comprehensive: 399600
#     Basic: 398554
#
# Value counts for column 'Previous Claims':
#     0.0: 305433
#     1.0: 300811
#     2.0: 167661
#     3.0: 49011
#     4.0: 10668
#     5.0: 2018
#     6.0: 302
#     7.0: 58
#     8.0: 8
#     9.0: 1
#
# Value counts for column 'Vehicle Age':
#     17.0: 62577
#     0.0: 61615
#     11.0: 61483
#     18.0: 61399
#     10.0: 61351
#     15.0: 60817
#     14.0: 60815
#     12.0: 60718
#     19.0: 60495
#     16.0: 60314
#     9.0: 59833
#     2.0: 59741
#     7.0: 59700
#     5.0: 59499
#     3.0: 59058
#     13.0: 58684
#     8.0: 58298
#     4.0: 58148
#     6.0: 58084
#     1.0: 57365
#
# Value counts for column 'Insurance Duration':
#     9.0: 137781
#     1.0: 135072
#     8.0: 133800
#     7.0: 133592
#     5.0: 132253
#     4.0: 132182
#     6.0: 132141
#     3.0: 132018
#     2.0: 131160
#
# Value counts for column 'Customer Feedback':
#     Average: 377905
#     Poor: 375518
#     Good: 368753
#
# Value counts for column 'Smoking Status':
#     Yes: 601873
#     No: 598127
#
# Value counts for column 'Exercise Frequency':
#     Weekly: 306179
#     Monthly: 299830
#     Rarely: 299420
#     Daily: 294571
#
# Value counts for column 'Property Type':
#     House: 400349
#     Apartment: 399978
#     Condo: 399673

# %%
def plot_low_value_count_columns(df):
    background_color = '#5fa1bc'
    sns.set_theme(style="whitegrid", rc={"axes.facecolor": background_color})
    
    low_value_count_columns = [col for col in df.columns if df[col].nunique() < 20]
    num_plots = len(low_value_count_columns)
    num_rows = (num_plots + 1) // 2  
    num_cols = 2 
    
    fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 5 * num_rows))
    axs = axs.flatten()
    
    for i, col in enumerate(low_value_count_columns):
        p = sns.countplot(y=col, data=df, palette='magma', edgecolor='white', linewidth=2, ax=axs[i], order=df[col].value_counts().index)
        for container in p.containers:
            plt.bar_label(container, label_type='center', color="black", fontsize=10, weight='bold', padding=6, position=(0.5, 0.5),
                          bbox={"boxstyle": "round", "pad": 0.2, "facecolor": "white", "edgecolor": "black", "linewidth": 2, "alpha": 1})
    
    plt.tight_layout()
    plt.show()

plot_low_value_count_columns(df_tr)

# %%
df_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200000 entries, 0 to 1199999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1200000 non-null  int64
#  1   Age                   1181295 non-null  float64
#  2   Gender                1200000 non-null  object
#  3   Annual Income         1155051 non-null  float64
#  4   Marital Status        1181471 non-null  object
#  5   Number of Dependents  1090328 non-null  float64
#  6   Education Level       1200000 non-null  object
#  7   Occupation            841925 non-null   object
#  8   Health Score          1125924 non-null  float64
#  9   Location              1200000 non-null  object
#  10  Policy Type           1200000 non-null  object
#  11  Previous Claims       835971 non-null   float64
#  12  Vehicle Age           1199994 non-null  float64
#  13  Credit Score          1062118 non-null  float64
#  14  Insurance Duration    1199999 non-null  float64
#  15  Policy Start Date     1200000 non-null  object
#  16  Customer Feedback     1122176 non-null  object
#  17  Smoking Status        1200000 non-null  object
#  18  Exercise Frequency    1200000 non-null  object
#  19  Property Type         1200000 non-null  object
#  20  Premium Amount        1200000 non-null  float64
# dtypes: float64(9), int64(1), object(11)
# memory usage: 192.3+ MB

# %%
numerical_columns = ['Age', 'Annual Income', 'Number of Dependents', 'Health Score',
                     'Vehicle Age', 'Credit Score', 'Insurance Duration']
numerical_columns = [col for col in df_tr.select_dtypes(include=['number']).columns if col != 'Target']

fig, axes = plt.subplots(nrows=len(numerical_columns), ncols=1, figsize=(10, len(numerical_columns)*4))

axes = axes.flatten()

for i, col in enumerate(numerical_columns):
    sns.histplot(df_tr[col], kde=True, ax=axes[i])
    axes[i].set_title(f'{col} Distribution')
    axes[i].tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %%
def fill_nulls(train_df, test_df, target_col):
    # Separate the target column from the train data
    X_train = train_df.drop(columns=[target_col])
    y_train = train_df[target_col]
    
    # Identify numeric and categorical columns
    numeric_cols = X_train.select_dtypes(include=['float64', 'int64']).columns
    categorical_cols = X_train.select_dtypes(include=['object', 'category']).columns
    
    # Create imputers
    iterative_imputer = IterativeImputer(max_iter=10, random_state=42)  # For numeric columns
    categorical_imputer = SimpleImputer(strategy='constant', fill_value='Unknown')  # For categorical columns
    
    # Impute numeric columns
    X_train[numeric_cols] = iterative_imputer.fit_transform(X_train[numeric_cols])
    test_df[numeric_cols] = iterative_imputer.transform(test_df[numeric_cols])
    
    # Impute categorical columns
    X_train[categorical_cols] = categorical_imputer.fit_transform(X_train[categorical_cols])
    test_df[categorical_cols] = categorical_imputer.transform(test_df[categorical_cols])
    
    # Reattach the target column to the train dataset
    train_df_filled = X_train.copy()
    train_df_filled[target_col] = y_train

    return train_df_filled, test_df

# Apply the function
df_tr_filled, df_ts_filled = fill_nulls(df_tr, df_ts, target_col='Premium Amount')

# %%
def convert_to_category(df):
    for col in df.columns:
        if df[col].dtype == 'object':  
            df[col] = df[col].astype('category')
    return df

df_tr_category = convert_to_category(df_tr_filled)
df_ts_category = convert_to_category(df_ts_filled)

# %% [markdown]
# # <p style="font-family: 'Amiri'; font-size: 3rem; color: yellow; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #5fa1bc; padding: 20px; border-radius: 20px; border: 7px solid yellow; width:95%">˚ ༘ ೀ⋆｡ Machine Learning ˚ ༘ ೀ⋆｡ ˚</p>

# %%
X = df_tr_category.drop(columns=['Premium Amount'], axis=1)
y = df_tr_category['Premium Amount']

y_log = np.log1p(y)  

def rmsle(y_true, y_pred):
    return np.sqrt(np.mean((np.log1p(y_pred) - np.log1p(y_true))**2))

cat_features = [X.columns.get_loc(col) for col in X.select_dtypes(include=['category']).columns]

catboost_model = CatBoostRegressor(
    iterations=1000, 
    learning_rate=0.1, 
    depth=6, 
    random_seed=42, 
    task_type="GPU",  
    devices="0"       
)

kf = KFold(n_splits=10, shuffle=True, random_state=42)

rmsle_scores = []
train_rmsle_scores = []  

# Cross-validation loop
for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"Fold {fold + 1}")
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y_log.iloc[train_idx], y_log.iloc[val_idx]  
    
    # Train the model
    catboost_model.fit(
        X_train, y_train, 
        eval_set=(X_val, y_val), 
        cat_features=cat_features,
        early_stopping_rounds=50, 
        verbose=0
    )
    
    # Predictions for validation and training data
    y_pred_val = catboost_model.predict(X_val)
    y_pred_train = catboost_model.predict(X_train)
    
    # Calculate RMSLE for validation and training
    fold_rmsle_val = rmsle(np.expm1(y_val), np.maximum(np.expm1(y_pred_val), 0))  
    fold_rmsle_train = rmsle(np.expm1(y_train), np.maximum(np.expm1(y_pred_train), 0))  
    
    rmsle_scores.append(fold_rmsle_val)
    train_rmsle_scores.append(fold_rmsle_train)
    
    print(f"Fold RMSLE (Validation): {fold_rmsle_val:.4f}")
    print(f"Fold RMSLE (Training): {fold_rmsle_train:.4f}")

# Calculate mean and standard deviation of RMSLE scores
mean_rmsle = np.mean(rmsle_scores)
std_rmsle = np.std(rmsle_scores)
mean_train_rmsle = np.mean(train_rmsle_scores)
std_train_rmsle = np.std(train_rmsle_scores)

# Output results
print(f"Mean RMSLE (Validation): {mean_rmsle:.4f}")
print(f"Standard Deviation of RMSLE (Validation): {std_rmsle:.4f}")
print(f"Mean RMSLE (Training): {mean_train_rmsle:.4f}")
print(f"Standard Deviation of RMSLE (Training): {std_train_rmsle:.4f}")
# Out:
# Fold 1
# Fold RMSLE (Validation): 1.0623
# Fold RMSLE (Training): 1.0578
# Fold 2
# Fold RMSLE (Validation): 1.0618
# Fold RMSLE (Training): 1.0582
# Fold 3
# Fold RMSLE (Validation): 1.0639
# Fold RMSLE (Training): 1.0568
# Fold 4
# Fold RMSLE (Validation): 1.0583
# Fold RMSLE (Training): 1.0586
# Fold 5
# Fold RMSLE (Validation): 1.0639
# Fold RMSLE (Training): 1.0584
# Fold 6
# Fold RMSLE (Validation): 1.0594
# Fold RMSLE (Training): 1.0571
# Fold 7
# Fold RMSLE (Validation): 1.0596
# Fold RMSLE (Training): 1.0578
# Fold 8
# Fold RMSLE (Validation): 1.0613
# Fold RMSLE (Training): 1.0573
# Fold 9
# Fold RMSLE (Validation): 1.0575
# Fold RMSLE (Training): 1.0568
# Fold 10
# Fold RMSLE (Validation): 1.0659
# Fold RMSLE (Training): 1.0567
# Mean RMSLE (Validation): 1.0614
# Standard Deviation of RMSLE (Validation): 0.0026
# Mean RMSLE (Training): 1.0575
# Standard Deviation of RMSLE (Training): 0.0007

# %% [markdown]
# <!-- X = df_tr_encoded.drop(columns=['Premium Amount'], axis=1)
# y = df_tr_encoded['Premium Amount']
#
# y_log = np.log1p(y)  okey okey anything else ?
#
# def rmsle(y_true, y_pred):
#     return np.sqrt(np.mean((np.log1p(y_pred) - np.log1p(y_true))**2))
#
# cat_features = [col for col in X.select_dtypes(include=['category']).columns]
#
# X_encoded = X.copy()
# for col in cat_features:
#     X_encoded[col] = X_encoded[col].cat.codes
#
# catboost_model = CatBoostRegressor(
#     iterations=1000,
#     learning_rate=0.1,
#     depth=6,
#     random_seed=42,
#     task_type="GPU",
#     devices="0"
# )
#
# kf = KFold(n_splits=10, shuffle=True, random_state=42)
#
# rmsle_scores = []
# train_rmsle_scores = []
#
# for fold, (train_idx, val_idx) in enumerate(kf.split(X_encoded)):
#     print(f"Fold {fold + 1}")
#     X_train, X_val = X_encoded.iloc[train_idx], X_encoded.iloc[val_idx]
#     y_train, y_val = y_log.iloc[train_idx], y_log.iloc[val_idx]  # Use log-transformed target
#
#     catboost_model.fit(
#         X_train, y_train,
#         eval_set=(X_val, y_val),
#         cat_features=cat_features,
#         early_stopping_rounds=50,
#         verbose=0
#     )
#
#     y_pred_val = catboost_model.predict(X_val)
#     y_pred_train = catboost_model.predict(X_train)
#
#     fold_rmsle_val = rmsle(np.expm1(y_val), np.maximum(np.expm1(y_pred_val), 0))  # Inverse log transformation for RMSLE
#     fold_rmsle_train = rmsle(np.expm1(y_train), np.maximum(np.expm1(y_pred_train), 0))  # Inverse log transformation for RMSLE
#
#     rmsle_scores.append(fold_rmsle_val)
#     train_rmsle_scores.append(fold_rmsle_train)
#
#     print(f"Fold RMSLE (Validation): {fold_rmsle_val:.4f}")
#     print(f"Fold RMSLE (Training): {fold_rmsle_train:.4f}")
#
# mean_rmsle = np.mean(rmsle_scores)
# std_rmsle = np.std(rmsle_scores)
# mean_train_rmsle = np.mean(train_rmsle_scores)
# std_train_rmsle = np.std(train_rmsle_scores)
#
# print(f"Mean RMSLE (Validation): {mean_rmsle:.4f}")
# print(f"Standard Deviation of RMSLE (Validation): {std_rmsle:.4f}")
# print(f"Mean RMSLE (Training): {mean_train_rmsle:.4f}")
# print(f"Standard Deviation of RMSLE (Training): {std_train_rmsle:.4f}")
#  -->

# %% [markdown]
# # <p style="font-family: 'Amiri'; font-size: 3rem; color: yellow; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #5fa1bc; padding: 20px; border-radius: 20px; border: 7px solid yellow; width:95%">˚ ༘ ೀ⋆｡ Submission˚ ༘ ೀ⋆｡ ˚</p>

# %%
L_pred_log = catboost_model.predict(df_ts_category)

L_pred = np.expm1(L_pred_log)

print(L_pred)
# Out:
# [809.99084674 857.0935509  759.66477181 ... 780.05243569 791.99175524
#  775.22914844]

# %%
df_s['Premium Amount'] = L_pred
df_s.to_csv('L_Submission_now.csv', index=False)

# %%
df_s.head()
# Out:
#         id  Premium Amount
# 0  1200000      809.990847
# 1  1200001      857.093551
# 2  1200002      759.664772
# 3  1200003      763.512171
# 4  1200004      777.286750

# %% [markdown]
# # <p style="font-family: 'Amiri'; font-size: 3rem; color: yellow; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #5fa1bc; padding: 20px; border-radius: 20px; border: 7px solid yellow; width:95%">˚ ༘ ೀ⋆｡ Thanks Alot For Reading I am WORKING ON 2ND version to get higher accuracy i will share that soon :)  ༘ ೀ⋆｡ ˚</p>
